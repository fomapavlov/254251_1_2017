# %% [markdown]
# # โครงสร้างข้อมูลฉบับภาษาไพทอน
#
# เอกสารประกอบการสอนรายวิชาโครงสร้างข้อมูลถูกสร้างขึ้นจาก python notebook ซึ่งเป็นเครื่องมือที่ถูกใช้ในการผลิตสื่อการสอนภาษาไพทอนอย่างแพร่หลายในระดับสากลเนื่องจากมีคุณสมบัติในการให้ความรู้ผ่านเนื้อหาควบคู่กับการเขียนรหัสแบบโต้ตอบ จึงเป็นแรงผลักดันให้ผู้สอนพัฒนาเอกสารประกอบการสอนผ่าน python notebook เพื่อตอบสนองนโนบาย education 4.0 การพัฒนาเอกสารประกอบการสอนที่มีความทันสมัย และผลสัมฤทธิ์ที่จะเกิดขึ้นกับนิสิตเป็นหลัก ดังนั้นหากไม่เป็นไปตามรูปแบบที่คณะกรรมการผู้ประเมินคุ้นเคยทางผู้สอนขอความอนุเคราะห์และขออภัยไว้ ณ ที่นี้
#
# เรื่องการใช้ภาษาผู้สอนมีเจตนาที่จะใช้ตามหลักของราชบัณฑิต แต่จะมีตัวย่อบางตัวเช่น ADT BST ที่ตั้งใจใช้เพื่อลดความเยิ่นเย้อ ในส่วนของภาษาอังกฤษคำอื่น เช่น list string queue ฯลฯ ล้วนเป็นการอ้างถึงชนิดข้อมูลหรือคลาสของภาษาไพทอน หรือคลาสที่สร้างขึ้น หาได้เป็นการใช้ภาษาอังกฤษแทรกในภาษาไทยไม่ นอกจากนี้ python notebook ยังมีข้อจำกัดเกี่ยวกับการแสดงผลสูตรทางคณิตศาสตร์ที่ใช้ฟอนท์ต่างจากส่วนของเนื้อหา
#
# ในแง่ของเนื้อหาส่วนใหญ่ได้ถูกแปล ดัดแปลง และเรียบเรียงจาก [interactivepython](http://interactivepython.org/runestone/static/pythonds/index.html) ดังนั้นจึงมีการนำรูปมาใช้โดยทุกครั้งจะมีการอ้างอิงไปสู่เวบไซต์ต้นฉบับ การอ้างอิงถึงรูปและตารางใน python notebook จะแตกต่างจากเอกสารทั่วไปโดยได้ทำการกำหนดลิงก์เพื่อสามารถกดเข้าถึงรูปหรือตารางนั้นๆ ได้โดยตรง
